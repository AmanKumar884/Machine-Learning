# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("chessgame.csv")
df.head(10)
# Out:
#          id  rated    created_at  last_move_at  turns victory_status winner  \
# 0  TZJHLljE  False  1.504210e+12  1.504210e+12     13      outoftime  white
# 1  l1NXvwaE   True  1.504130e+12  1.504130e+12     16         resign  black
# 2  mIICvQHh   True  1.504130e+12  1.504130e+12     61           mate  white
# 3  kWKvrqYL   True  1.504110e+12  1.504110e+12     61           mate  white
# 4  9tXo1AUZ   True  1.504030e+12  1.504030e+12     95           mate  white
# 5  MsoDV9wj  False  1.504240e+12  1.504240e+12      5           draw   draw
# 6  qwU9rasv   True  1.504230e+12  1.504230e+12     33         resign  white
# 7  RVN0N3VK  False  1.503680e+12  1.503680e+12      9         resign  black
# 8  dwF3DJHO   True  1.503510e+12  1.503510e+12     66         resign  black
# 9  afoMwnLg   True  1.503440e+12  1.503440e+12    119           mate  white
#
#   increment_code            white_id  white_rating            black_id  \
# 0           15+2            bourgris          1500                a-00
# 1           5+10                a-00          1322           skinnerua
# 2           5+10              ischia          1496                a-00
# 3           20+0       daniamurashov          1439        adivanov2009
# 4           30+3           nik221107          1523        adivanov2009
# 5           10+0           trelynn17          1250       franklin14532
# 6           10+0             capa_jr          1520  daniel_likes_chess
# 7          15+30  daniel_likes_chess          1413            soultego
# 8           15+0           ehabfanri          1439  daniel_likes_chess
# 9           10+0  daniel_likes_chess          1381             mirco25
#
#    black_rating                                              moves  \
# 0          1191  d4 d5 c4 c6 cxd5 e6 dxe6 fxe6 Nf3 Bb4+ Nc3 Ba5...
# 1          1261  d4 Nc6 e4 e5 f4 f6 dxe5 fxe5 fxe5 Nxe5 Qd4 Nc6...
# 2          1500  e4 e5 d3 d6 Be3 c6 Be2 b5 Nd2 a5 a4 c5 axb5 Nc...
# 3          1454  d4 d5 Nf3 Bf5 Nc3 Nf6 Bf4 Ng4 e3 Nc6 Be2 Qd7 O...
# 4          1469  e4 e5 Nf3 d6 d4 Nc6 d5 Nb4 a3 Na6 Nc3 Be7 b4 N...
# 5          1002                                   e4 c5 Nf3 Qa5 a3
# 6          1423  d4 d5 e4 dxe4 Nc3 Nf6 f3 exf3 Nxf3 Nc6 Bb5 a6 ...
# 7          2108                     e4 Nc6 d4 e5 d5 Nce7 c3 Ng6 b4
# 8          1392  e4 e5 Bc4 Nc6 Nf3 Nd4 d3 Nxf3+ Qxf3 Nf6 h3 Bc5...
# 9          1209  e4 d5 exd5 Qxd5 Nc3 Qe5+ Be2 Na6 d4 Qf5 Bxa6 b...
#
#   opening_eco                                       opening_name  opening_ply
# 0         D10                   Slav Defense: Exchange Variation            5
# 1         B00             Nimzowitsch Defense: Kennedy Variation            4
# 2         C20              King's Pawn Game: Leonardis Variation            3
# 3         D02             Queen's Pawn Game: Zukertort Variation            3
# 4         C41                                   Philidor Defense            5
# 5         B27               Sicilian Defense: Mongoose Variation            4
# 6         D00         Blackmar-Diemer Gambit: Pietrowsky Defense           10
# 7         B00  Nimzowitsch Defense: Kennedy Variation |  Link...            5
# 8         C50              Italian Game: Schilling-Kostic Gambit            6
# 9         B01      Scandinavian Defense: Mieses-Kotroc Variation            4

# %%
df.winner.count()
# Out:
# 20058

# %%
df.winner.nunique()
# Out:
# 3

# %%
df['winner'].unique()
# Out:
# array(['white', 'black', 'draw'], dtype=object)

# %%
df['winner'].value_counts()
# Out:
# white    10001
# black     9107
# draw       950
# Name: winner, dtype: int64

# %%
df.isnull().sum()
# Out:
# id                0
# rated             0
# created_at        0
# last_move_at      0
# turns             0
# victory_status    0
# winner            0
# increment_code    0
# white_id          0
# white_rating      0
# black_id          0
# black_rating      0
# moves             0
# opening_eco       0
# opening_name      0
# opening_ply       0
# dtype: int64

# %%
df['victory_status'].value_counts()
# Out:
# resign       11147
# mate          6325
# outoftime     1680
# draw           906
# Name: victory_status, dtype: int64

# %%
df['white_rating'].mean()
# Out:
# 1596.6318675840064

# %%
df['black_rating'].mean()
# Out:
# 1588.8319872370128

# %%
df['increment_code'].value_counts()
# Out:
# 10+0      7721
# 15+0      1311
# 15+15      850
# 5+5        738
# 5+8        697
# 8+0        588
# 10+5       579
# 15+10      461
# 20+0       448
# 30+0       375
# 10+10      355
# 15+5       314
# 7+2        265
# 10+2       187
# 30+30      169
# 5+10       155
# 25+0       152
# 10+3       149
# 10+8       123
# 20+10      103
# 10+15      103
# 15+2       100
# 45+45       97
# 9+0         94
# 20+5        88
# 8+8         81
# 180+0       76
# 30+10       75
# 15+8        75
# 8+5         70
#           ...
# 30+40        1
# 20+120       1
# 1+13         1
# 8+25         1
# 30+60        1
# 60+4         1
# 35+8         1
# 30+7         1
# 4+18         1
# 19+3         1
# 60+20        1
# 40+9         1
# 150+60       1
# 21+0         1
# 180+3        1
# 17+16        1
# 0+20         1
# 120+5        1
# 12+20        1
# 6+30         1
# 30+150       1
# 45+2         1
# 3+35         1
# 35+15        1
# 19+8         1
# 15+25        1
# 20+11        1
# 7+18         1
# 4+9          1
# 10+180       1
# Name: increment_code, Length: 400, dtype: int64

# %%
df['opening_name'].value_counts()
# Out:
# Van't Kruijs Opening                                                   368
# Sicilian Defense                                                       358
# Sicilian Defense: Bowdler Attack                                       296
# Scotch Game                                                            271
# French Defense: Knight Variation                                       271
# Scandinavian Defense: Mieses-Kotroc Variation                          259
# Queen's Pawn Game: Mason Attack                                        232
# Queen's Pawn Game: Chigorin Variation                                  229
# Scandinavian Defense                                                   223
# Horwitz Defense                                                        209
# Caro-Kann Defense                                                      199
# Philidor Defense #3                                                    198
# Philidor Defense #2                                                    193
# Indian Game                                                            181
# Italian Game: Anti-Fried Liver Defense                                 180
# Four Knights Game: Italian Variation                                   176
# Modern Defense                                                         174
# Owen Defense                                                           168
# King's Pawn Game: Wayward Queen Attack                                 164
# Sicilian Defense: Old Sicilian                                         159
# King's Pawn Game: Leonardis Variation                                  154
# Queen's Pawn Game                                                      142
# Philidor Defense                                                       135
# Ruy Lopez: Steinitz Defense                                            134
# Hungarian Opening                                                      130
# Queen's Pawn                                                           129
# French Defense: Normal Variation                                       129
# Bishop's Opening                                                       128
# Queen's Gambit Refused: Marshall Defense                               127
# Queen's Pawn Game #2                                                   118
#                                                                       ...
# Ruy Lopez: Alapin Defense                                                1
# King's Indian Defense: Fianchetto Variation |  Classical Fianchetto      1
# Old Indian: Czech Variation                                              1
# Polish Opening: Tartakower Gambit                                        1
# Benoni Defense: Taimanov Variation                                       1
# Alekhine Defense: Four Pawns Attack |  Fianchetto Variation              1
# Englund Gambit Complex: Soller Gambit Deferred                           1
# Petrov's Defense #5                                                      1
# Caro-Kann Defense: Panov Attack |  Gunderam Attack                       1
# Sicilian Defense: Nimzo-American Variation                               1
# Goldsmith Defense: Picklepuss Defense                                    1
# Philidor Defense: Lion Variation |  Lion's Claw II                       1
# Dutch Defense: Staunton Gambit |  Nimzowitsch Variation                  1
# Nimzo-Indian Defense: Classical |  Noa Variation |  5.cxd5 exd5          1
# Sicilian Defense: Richter-Rauzer Variation |  Vitolins Variation         1
# King's Indian Defense: Semi-Classical Variation |  Benoni Variation      1
# King's Gambit Accepted |  Rosentreter Gambit                             1
# Sicilian Defense: Double-Dutch Gambit                                    1
# English Opening: Anglo-Indian Defense |  Anglo-Gruenfeld Variation       1
# Benoni Defense: Classical Variation |  Main Line                         1
# Tarrasch Defense: Classical Variation |  Carlsbad Variation              1
# Queen's Indian Defense: Fianchetto Variation |  Check Variation          1
# Queen's Gambit Declined: Slav |  Dutch Variation                         1
# Nimzo-Indian Defense: Romanishin Variation #2                            1
# Queen's Gambit Declined: Modern Variation |  Heral Variation             1
# Polish Opening: Dutch Defense                                            1
# Caro-Kann Defense: Classical Variation |  Lobron System                  1
# Queen's Gambit Accepted: Deferred Variation                              1
# Nimzo-Indian Defense: Saemisch Variation                                 1
# Neo-Gruenfeld Defense: Classical Variation                               1
# Name: opening_name, Length: 1477, dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'rated', 'created_at', 'last_move_at', 'turns', 'victory_status',
#        'winner', 'increment_code', 'white_id', 'white_rating', 'black_id',
#        'black_rating', 'moves', 'opening_eco', 'opening_name', 'opening_ply'],
#       dtype='object')

# %%
df.drop(['white_id'],axis='columns')
df.head(20)
# Out:
#           id  rated    created_at  last_move_at  turns victory_status winner  \
# 0   TZJHLljE  False  1.504210e+12  1.504210e+12     13      outoftime  white
# 1   l1NXvwaE   True  1.504130e+12  1.504130e+12     16         resign  black
# 2   mIICvQHh   True  1.504130e+12  1.504130e+12     61           mate  white
# 3   kWKvrqYL   True  1.504110e+12  1.504110e+12     61           mate  white
# 4   9tXo1AUZ   True  1.504030e+12  1.504030e+12     95           mate  white
# 5   MsoDV9wj  False  1.504240e+12  1.504240e+12      5           draw   draw
# 6   qwU9rasv   True  1.504230e+12  1.504230e+12     33         resign  white
# 7   RVN0N3VK  False  1.503680e+12  1.503680e+12      9         resign  black
# 8   dwF3DJHO   True  1.503510e+12  1.503510e+12     66         resign  black
# 9   afoMwnLg   True  1.503440e+12  1.503440e+12    119           mate  white
# 10  HgKLWPsz  False  1.503350e+12  1.503350e+12     39           mate  white
# 11  Vf5fKWzI  False  1.503350e+12  1.503350e+12     38         resign  black
# 12  HRti5mKv  False  1.503350e+12  1.503350e+12     60         resign  black
# 13  2fEjSei6  False  1.503340e+12  1.503340e+12     31         resign  black
# 14  u7i6dOaJ  False  1.504090e+12  1.504100e+12     31           mate  white
# 15  guanvMR5  False  1.504090e+12  1.504090e+12     43         resign  black
# 16  PmpkWkmm  False  1.504090e+12  1.504090e+12     52         resign  black
# 17  EwaK0IsE  False  1.504010e+12  1.504010e+12     66           mate  black
# 18  yrSDozT3  False  1.504010e+12  1.504010e+12    101         resign  black
# 19  x31mXlvc  False  1.503760e+12  1.503760e+12     25         resign  white
#
#    increment_code            white_id  white_rating            black_id  \
# 0            15+2            bourgris          1500                a-00
# 1            5+10                a-00          1322           skinnerua
# 2            5+10              ischia          1496                a-00
# 3            20+0       daniamurashov          1439        adivanov2009
# 4            30+3           nik221107          1523        adivanov2009
# 5            10+0           trelynn17          1250       franklin14532
# 6            10+0             capa_jr          1520  daniel_likes_chess
# 7           15+30  daniel_likes_chess          1413            soultego
# 8            15+0           ehabfanri          1439  daniel_likes_chess
# 9            10+0  daniel_likes_chess          1381             mirco25
# 10          20+60  daniel_likes_chess          1381            anaissac
# 11          20+60  daniel_likes_chess          1381           subham777
# 12           5+40  daniel_likes_chess          1381       roman12342005
# 13            8+0  daniel_likes_chess          1381              alkhan
# 14          15+15   shivangithegenius          1094       sureka_akshat
# 15          15+15       sureka_akshat          1141   shivangithegenius
# 16          15+15   shivangithegenius          1094       sureka_akshat
# 17          15+16       sureka_akshat          1141   shivangithegenius
# 18          15+15   shivangithegenius          1094           slam_ment
# 19           11+0               g-ios          1500   shivangithegenius
#
#     black_rating                                              moves  \
# 0           1191  d4 d5 c4 c6 cxd5 e6 dxe6 fxe6 Nf3 Bb4+ Nc3 Ba5...
# 1           1261  d4 Nc6 e4 e5 f4 f6 dxe5 fxe5 fxe5 Nxe5 Qd4 Nc6...
# 2           1500  e4 e5 d3 d6 Be3 c6 Be2 b5 Nd2 a5 a4 c5 axb5 Nc...
# 3           1454  d4 d5 Nf3 Bf5 Nc3 Nf6 Bf4 Ng4 e3 Nc6 Be2 Qd7 O...
# 4           1469  e4 e5 Nf3 d6 d4 Nc6 d5 Nb4 a3 Na6 Nc3 Be7 b4 N...
# 5           1002                                   e4 c5 Nf3 Qa5 a3
# 6           1423  d4 d5 e4 dxe4 Nc3 Nf6 f3 exf3 Nxf3 Nc6 Bb5 a6 ...
# 7           2108                     e4 Nc6 d4 e5 d5 Nce7 c3 Ng6 b4
# 8           1392  e4 e5 Bc4 Nc6 Nf3 Nd4 d3 Nxf3+ Qxf3 Nf6 h3 Bc5...
# 9           1209  e4 d5 exd5 Qxd5 Nc3 Qe5+ Be2 Na6 d4 Qf5 Bxa6 b...
# 10          1272  e3 e6 d4 d6 Bd3 c6 Nf3 Be7 Nc3 Nf6 Bd2 Bd7 Qe2...
# 11          1867  e4 e6 d4 d5 e5 c5 c3 Nc6 Nf3 Qb6 Be3 Qxb2 Nbd2...
# 12          1936  e4 e6 Nf3 d5 exd5 exd5 Qe2+ Be7 Nc3 Nf6 d4 O-O...
# 13          1607  e4 e6 Qh5 g6 Qe5 Nf6 d4 d6 Qb5+ Bd7 Qxb7 Bc6 Q...
# 14          1141  e4 e5 Nf3 Nc6 Bc4 Nf6 Nc3 Bc5 O-O O-O d3 Ne8 B...
# 15          1094  e4 e5 Nf3 Nc6 Bc4 Nf6 Ng5 Qe7 O-O Nxe4 Nxe4 h6...
# 16          1141  e4 e5 Nf3 Nc6 Bc4 Nf6 Nc3 Bc5 O-O O-O Ne1 d6 d...
# 17          1094  e4 e5 Nf3 Nc6 Bc4 Nf6 Nc3 Bc5 O-O O-O Ne1 Ne8 ...
# 18          1300  e4 e5 Nf3 d6 Bc4 Be6 d3 Bxc4 dxc4 c5 O-O h6 Nc...
# 19          1094  d4 d5 h3 Nc6 Nf3 Nf6 Bg5 h6 Bxf6 exf6 e3 Bb4+ ...
#
#    opening_eco                                       opening_name  opening_ply
# 0          D10                   Slav Defense: Exchange Variation            5
# 1          B00             Nimzowitsch Defense: Kennedy Variation            4
# 2          C20              King's Pawn Game: Leonardis Variation            3
# 3          D02             Queen's Pawn Game: Zukertort Variation            3
# 4          C41                                   Philidor Defense            5
# 5          B27               Sicilian Defense: Mongoose Variation            4
# 6          D00         Blackmar-Diemer Gambit: Pietrowsky Defense           10
# 7          B00  Nimzowitsch Defense: Kennedy Variation |  Link...            5
# 8          C50              Italian Game: Schilling-Kostic Gambit            6
# 9          B01      Scandinavian Defense: Mieses-Kotroc Variation            4
# 10         A00                               Van't Kruijs Opening            1
# 11         C02  French Defense: Advance Variation |  Paulsen A...            9
# 12         C00                   French Defense: Knight Variation            3
# 13         C00                                  French Defense #2            2
# 14         C50               Four Knights Game: Italian Variation            8
# 15         C57  Italian Game: Two Knights Defense |  Knight At...            7
# 16         C50               Four Knights Game: Italian Variation            8
# 17         C50               Four Knights Game: Italian Variation            8
# 18         C41                                Philidor Defense #3            5
# 19         D00                                  Queen's Pawn Game            2

# %%
df = df.drop(labels=["black_id", "white_id"], axis=1)
df.head(10)
# Out:
#          id  rated    created_at  last_move_at  turns victory_status winner  \
# 0  TZJHLljE  False  1.504210e+12  1.504210e+12     13      outoftime  white
# 1  l1NXvwaE   True  1.504130e+12  1.504130e+12     16         resign  black
# 2  mIICvQHh   True  1.504130e+12  1.504130e+12     61           mate  white
# 3  kWKvrqYL   True  1.504110e+12  1.504110e+12     61           mate  white
# 4  9tXo1AUZ   True  1.504030e+12  1.504030e+12     95           mate  white
# 5  MsoDV9wj  False  1.504240e+12  1.504240e+12      5           draw   draw
# 6  qwU9rasv   True  1.504230e+12  1.504230e+12     33         resign  white
# 7  RVN0N3VK  False  1.503680e+12  1.503680e+12      9         resign  black
# 8  dwF3DJHO   True  1.503510e+12  1.503510e+12     66         resign  black
# 9  afoMwnLg   True  1.503440e+12  1.503440e+12    119           mate  white
#
#   increment_code  white_rating  black_rating  \
# 0           15+2          1500          1191
# 1           5+10          1322          1261
# 2           5+10          1496          1500
# 3           20+0          1439          1454
# 4           30+3          1523          1469
# 5           10+0          1250          1002
# 6           10+0          1520          1423
# 7          15+30          1413          2108
# 8           15+0          1439          1392
# 9           10+0          1381          1209
#
#                                                moves opening_eco  \
# 0  d4 d5 c4 c6 cxd5 e6 dxe6 fxe6 Nf3 Bb4+ Nc3 Ba5...         D10
# 1  d4 Nc6 e4 e5 f4 f6 dxe5 fxe5 fxe5 Nxe5 Qd4 Nc6...         B00
# 2  e4 e5 d3 d6 Be3 c6 Be2 b5 Nd2 a5 a4 c5 axb5 Nc...         C20
# 3  d4 d5 Nf3 Bf5 Nc3 Nf6 Bf4 Ng4 e3 Nc6 Be2 Qd7 O...         D02
# 4  e4 e5 Nf3 d6 d4 Nc6 d5 Nb4 a3 Na6 Nc3 Be7 b4 N...         C41
# 5                                   e4 c5 Nf3 Qa5 a3         B27
# 6  d4 d5 e4 dxe4 Nc3 Nf6 f3 exf3 Nxf3 Nc6 Bb5 a6 ...         D00
# 7                     e4 Nc6 d4 e5 d5 Nce7 c3 Ng6 b4         B00
# 8  e4 e5 Bc4 Nc6 Nf3 Nd4 d3 Nxf3+ Qxf3 Nf6 h3 Bc5...         C50
# 9  e4 d5 exd5 Qxd5 Nc3 Qe5+ Be2 Na6 d4 Qf5 Bxa6 b...         B01
#
#                                         opening_name  opening_ply
# 0                   Slav Defense: Exchange Variation            5
# 1             Nimzowitsch Defense: Kennedy Variation            4
# 2              King's Pawn Game: Leonardis Variation            3
# 3             Queen's Pawn Game: Zukertort Variation            3
# 4                                   Philidor Defense            5
# 5               Sicilian Defense: Mongoose Variation            4
# 6         Blackmar-Diemer Gambit: Pietrowsky Defense           10
# 7  Nimzowitsch Defense: Kennedy Variation |  Link...            5
# 8              Italian Game: Schilling-Kostic Gambit            6
# 9      Scandinavian Defense: Mieses-Kotroc Variation            4

# %%
for i in range(10):
    print(i+1)
    print(df.moves[i])
    print(df.turns[i])
# Out:
# 1
# d4 d5 c4 c6 cxd5 e6 dxe6 fxe6 Nf3 Bb4+ Nc3 Ba5 Bf4
# 13
# 2
# d4 Nc6 e4 e5 f4 f6 dxe5 fxe5 fxe5 Nxe5 Qd4 Nc6 Qe5+ Nxe5 c4 Bb4+
# 16
# 3
# e4 e5 d3 d6 Be3 c6 Be2 b5 Nd2 a5 a4 c5 axb5 Nc6 bxc6 Ra6 Nc4 a4 c3 a3 Nxa3 Rxa3 Rxa3 c4 dxc4 d5 cxd5 Qxd5 exd5 Be6 Ra8+ Ke7 Bc5+ Kf6 Bxf8 Kg6 Bxg7 Kxg7 dxe6 Kh6 exf7 Nf6 Rxh8 Nh5 Bxh5 Kg5 Rxh7 Kf5 Qf3+ Ke6 Bg4+ Kd6 Rh6+ Kc5 Qe3+ Kb5 c4+ Kb4 Qc3+ Ka4 Bd1#
# 61
# 4
# d4 d5 Nf3 Bf5 Nc3 Nf6 Bf4 Ng4 e3 Nc6 Be2 Qd7 O-O O-O-O Nb5 Nb4 Rc1 Nxa2 Ra1 Nb4 Nxa7+ Kb8 Nb5 Bxc2 Bxc7+ Kc8 Qd2 Qc6 Na7+ Kd7 Nxc6 bxc6 Bxd8 Kxd8 Qxb4 e5 Qb8+ Ke7 dxe5 Be4 Ra7+ Ke6 Qe8+ Kf5 Qxf7+ Nf6 Nh4+ Kg5 g3 Ng4 Qf4+ Kh5 Qxg4+ Kh6 Qf4+ g5 Qf6+ Bg6 Nxg6 Bg7 Qxg7#
# 61
# 5
# e4 e5 Nf3 d6 d4 Nc6 d5 Nb4 a3 Na6 Nc3 Be7 b4 Nf6 Bg5 O-O b5 Nc5 Bxf6 Bxf6 Bd3 Qd7 O-O Nxd3 Qxd3 c6 a4 cxd5 Nxd5 Qe6 Nc7 Qg4 Nxa8 Bd7 Nc7 Rc8 Nd5 Qg6 Nxf6+ Qxf6 Rfd1 Re8 Qxd6 Bg4 Qxf6 gxf6 Rd3 Bxf3 Rxf3 Rd8 Rxf6 Kg7 Rf3 Rd2 Rg3+ Kf8 c3 Re2 f3 Rc2 Rg5 f6 Rh5 Kg7 Rd1 Kg6 Rh3 Rxc3 Rd7 Rc1+ Kf2 Rc2+ Kg3 h5 Rxb7 Kg5 Rxa7 h4+ Rxh4 Rxg2+ Kxg2 Kxh4 b6 Kg5 b7 f5 exf5 Kxf5 b8=Q e4 Rf7+ Kg5 Qg8+ Kh6 Rh7#
# 95
# 6
# e4 c5 Nf3 Qa5 a3
# 5
# 7
# d4 d5 e4 dxe4 Nc3 Nf6 f3 exf3 Nxf3 Nc6 Bb5 a6 Bd3 Bg4 O-O Nxd4 Be2 Nxe2+ Qxe2 Bxf3 Qxf3 Qd4+ Be3 Qg4 Qxb7 Rd8 Qc6+ Nd7 Nd5 e6 Nxc7+ Ke7 Bd2
# 33
# 8
# e4 Nc6 d4 e5 d5 Nce7 c3 Ng6 b4
# 9
# 9
# e4 e5 Bc4 Nc6 Nf3 Nd4 d3 Nxf3+ Qxf3 Nf6 h3 Bc5 a3 O-O Be3 Bxe3 Qxe3 Re8 Qf3 c6 Nc3 b5 Bb3 Qa5 O-O Bb7 Ne2 c5 Rfd1 d6 c4 bxc4 dxc4 Rac8 Rd5 Bxd5 exd5 Qb6 Nc1 e4 Qf4 Nh5 Qg4 Nf6 Qf4 Qa5 Bc2 Qe1+ Kh2 Nh5 Qxd6 Qxf2 Bxe4 Rxe4 Nd3 Qg3+ Kg1 Qxd3 Rf1 Rce8 Qd7 Qe3+ Kh1 Ng3+ Kh2 Nxf1+
# 66
# 10
# e4 d5 exd5 Qxd5 Nc3 Qe5+ Be2 Na6 d4 Qf5 Bxa6 bxa6 Nf3 Qe6+ Be3 Bb7 Ng5 Qc4 Qh5 Bxg2 Qxf7+ Qxf7 Nxf7 Kxf7 Rg1 Bf3 Rg3 Bh5 Rh3 g6 Ne4 Nf6 Nc5 e6 Nxa6 Rc8 Bf4 Bg4 Rg3 c6 Nb4 Bxb4+ c3 Ba5 b4 Bc7 Bxc7 Rxc7 Rb1 e5 dxe5 Re8 f4 Rd7 Kf2 Rd2+ Kg1 Rxa2 exf6 Kxf6 Rxg4 Kf5 Rg2 Rxg2+ Kxg2 Re2+ Kf3 Re4 Ra1 Rxf4+ Kg3 Rg4+ Kh3 h5 Rxa7 g5 Rf7+ Kg6 Rf3 Rf4 Rxf4 gxf4 Kg2 Kg5 c4 h4 b5 cxb5 cxb5 Kg4 b6 f3+ Kf2 Kf4 b7 h3 b8=Q+ Ke4 Qb4+ Kd5 Kxf3 Ke5 Kg3 Kf6 Qe4 Kg5 Qf3 Kh6 Qg4 Kh7 Qg5 Kh8 Kf4 Kh7 Kf5 Kh8 Kf6 Kh7 Qg7#
# 119

# %%
games=pd.read_csv('chessgame.csv')
games.head(10)
games = (
    games.assign(
        opening_archetype=games.opening_name.map(
            lambda n: n.split(":")[0].split("|")[0].split("#")[0].strip()
        ),
        opening_moves=games.apply(lambda srs: srs['moves'].split(" ")[:srs['opening_ply']],
                                  axis=1)
    )
)

# %%
games.head(10)
# Out:
#          id  rated    created_at  last_move_at  turns victory_status winner  \
# 0  TZJHLljE  False  1.504210e+12  1.504210e+12     13      outoftime  white
# 1  l1NXvwaE   True  1.504130e+12  1.504130e+12     16         resign  black
# 2  mIICvQHh   True  1.504130e+12  1.504130e+12     61           mate  white
# 3  kWKvrqYL   True  1.504110e+12  1.504110e+12     61           mate  white
# 4  9tXo1AUZ   True  1.504030e+12  1.504030e+12     95           mate  white
# 5  MsoDV9wj  False  1.504240e+12  1.504240e+12      5           draw   draw
# 6  qwU9rasv   True  1.504230e+12  1.504230e+12     33         resign  white
# 7  RVN0N3VK  False  1.503680e+12  1.503680e+12      9         resign  black
# 8  dwF3DJHO   True  1.503510e+12  1.503510e+12     66         resign  black
# 9  afoMwnLg   True  1.503440e+12  1.503440e+12    119           mate  white
#
#   increment_code            white_id  white_rating            black_id  \
# 0           15+2            bourgris          1500                a-00
# 1           5+10                a-00          1322           skinnerua
# 2           5+10              ischia          1496                a-00
# 3           20+0       daniamurashov          1439        adivanov2009
# 4           30+3           nik221107          1523        adivanov2009
# 5           10+0           trelynn17          1250       franklin14532
# 6           10+0             capa_jr          1520  daniel_likes_chess
# 7          15+30  daniel_likes_chess          1413            soultego
# 8           15+0           ehabfanri          1439  daniel_likes_chess
# 9           10+0  daniel_likes_chess          1381             mirco25
#
#    black_rating                                              moves  \
# 0          1191  d4 d5 c4 c6 cxd5 e6 dxe6 fxe6 Nf3 Bb4+ Nc3 Ba5...
# 1          1261  d4 Nc6 e4 e5 f4 f6 dxe5 fxe5 fxe5 Nxe5 Qd4 Nc6...
# 2          1500  e4 e5 d3 d6 Be3 c6 Be2 b5 Nd2 a5 a4 c5 axb5 Nc...
# 3          1454  d4 d5 Nf3 Bf5 Nc3 Nf6 Bf4 Ng4 e3 Nc6 Be2 Qd7 O...
# 4          1469  e4 e5 Nf3 d6 d4 Nc6 d5 Nb4 a3 Na6 Nc3 Be7 b4 N...
# 5          1002                                   e4 c5 Nf3 Qa5 a3
# 6          1423  d4 d5 e4 dxe4 Nc3 Nf6 f3 exf3 Nxf3 Nc6 Bb5 a6 ...
# 7          2108                     e4 Nc6 d4 e5 d5 Nce7 c3 Ng6 b4
# 8          1392  e4 e5 Bc4 Nc6 Nf3 Nd4 d3 Nxf3+ Qxf3 Nf6 h3 Bc5...
# 9          1209  e4 d5 exd5 Qxd5 Nc3 Qe5+ Be2 Na6 d4 Qf5 Bxa6 b...
#
#   opening_eco                                       opening_name  opening_ply  \
# 0         D10                   Slav Defense: Exchange Variation            5
# 1         B00             Nimzowitsch Defense: Kennedy Variation            4
# 2         C20              King's Pawn Game: Leonardis Variation            3
# 3         D02             Queen's Pawn Game: Zukertort Variation            3
# 4         C41                                   Philidor Defense            5
# 5         B27               Sicilian Defense: Mongoose Variation            4
# 6         D00         Blackmar-Diemer Gambit: Pietrowsky Defense           10
# 7         B00  Nimzowitsch Defense: Kennedy Variation |  Link...            5
# 8         C50              Italian Game: Schilling-Kostic Gambit            6
# 9         B01      Scandinavian Defense: Mieses-Kotroc Variation            4
#
#         opening_archetype                                      opening_moves
# 0            Slav Defense                             [d4, d5, c4, c6, cxd5]
# 1     Nimzowitsch Defense                                  [d4, Nc6, e4, e5]
# 2        King's Pawn Game                                       [e4, e5, d3]
# 3       Queen's Pawn Game                                      [d4, d5, Nf3]
# 4        Philidor Defense                              [e4, e5, Nf3, d6, d4]
# 5        Sicilian Defense                                 [e4, c5, Nf3, Qa5]
# 6  Blackmar-Diemer Gambit  [d4, d5, e4, dxe4, Nc3, Nf6, f3, exf3, Nxf3, Nc6]
# 7     Nimzowitsch Defense                              [e4, Nc6, d4, e5, d5]
# 8            Italian Game                       [e4, e5, Bc4, Nc6, Nf3, Nd4]
# 9    Scandinavian Defense                               [e4, d5, exd5, Qxd5]

# %%
games_played = pd.concat([games['white_id'], games['black_id']]).value_counts()
games_played.reset_index(drop=True).plot.line(figsize=(16, 8), fontsize=18)

n_ge_2 = len(games_played[games_played > 1])
print(str(n_ge_2) + " players who have played at least two games.")

import matplotlib.pyplot as plt
plt.axvline(n_ge_2, color='green')

len(games_played)
# Out:
# 4466 players who have played at least two games.
# 15635

# %%
games_played[games_played > 1].sum()
# Out:
# 28947

# %%
opening_used = (pd.concat([
                   games.groupby('white_id')['opening_archetype'].value_counts(),
                   games.groupby('black_id')['opening_archetype'].value_counts()
                ])
                    .rename(index='openings_used')
                    .reset_index()
                    .rename(columns={'white_id': 'player_id', 'openings_used': 'times_used'})
                    .groupby(['player_id', 'opening_archetype']).sum()
               )

# %%
opening_used.head(10)
# Out:
#                                             times_used
# player_id           opening_archetype
# --jim--             Scandinavian Defense             1
# -0olo0-             French Defense                   1
# -l-_jedi_knight_-l- Guatemala Defense                1
#                     Hungarian Opening                3
#                     King's Gambit Accepted           1
#                     Owen Defense                     2
#                     Pirc Defense                     1
#                     Scandinavian Defense             4
# -mati-              Barnes Defense                   1
# -pavel-             Scandinavian Defense             1

# %%
(opening_used
     .reset_index()
     .groupby('player_id')
     .filter(lambda df: df.opening_archetype.isin(['Sicilian Defense']).any())
     .query('opening_archetype != "Sicilian Defense"')
     .groupby('opening_archetype')
     .times_used
     .sum()
     .sort_values(ascending=False)
     .to_frame()
     .pipe(lambda df: df.assign(times_used = df.times_used / df.times_used.sum()))
     .squeeze()
     .head(10)
)
# Out:
# opening_archetype
# French Defense          0.081564
# Italian Game            0.067175
# Queen's Pawn Game       0.060557
# Ruy Lopez               0.060095
# King's Pawn Game        0.046322
# Philidor Defense        0.043552
# English Opening         0.042475
# Scandinavian Defense    0.041474
# Caro-Kann Defense       0.034857
# Scotch Game             0.032779
# Name: times_used, dtype: float64

# %%
(opening_used
     .reset_index()
     .groupby('player_id')
     .filter(lambda df: df.opening_archetype.isin(["King's Gambit"]).any())
     .query('opening_archetype != "King\'s Gambit"')
     .groupby('opening_archetype')
     .times_used
     .sum()
     .sort_values(ascending=False)
     .to_frame()
     .pipe(lambda df: df.assign(times_used = df.times_used / df.times_used.sum()))
     .squeeze()
     .head(10)
)
# Out:
# opening_archetype
# Sicilian Defense        0.106635
# French Defense          0.073460
# King's Pawn Game        0.070300
# Queen's Pawn Game       0.063981
# Philidor Defense        0.063191
# Italian Game            0.052923
# Ruy Lopez               0.041864
# Scandinavian Defense    0.039494
# Four Knights Game       0.026856
# Bishop's Opening        0.026066
# Name: times_used, dtype: float64

# %%
import numpy as np

def threshold_map(n_opening, n_all):
    if pd.isnull(n_opening):
        return np.nan
    elif n_opening / n_all >= 1 / 4:
        return 5
    elif n_opening / n_all >= 1 / 8:
        return 4
    elif n_opening / n_all > 1 / 16:
        return 3
    else:
        return 2

recommendations = opening_used.unstack(-1).loc[:, 'times_used'].apply(
    lambda srs: srs.map(lambda v: threshold_map(v, srs.sum())),
    axis='columns'
)

# %%
recommendations.head()
# Out:
# opening_archetype    Alekhine Defense  Amar Opening  Amazon Attack  \
# player_id
# --jim--                           NaN           NaN            NaN
# -0olo0-                           NaN           NaN            NaN
# -l-_jedi_knight_-l-               NaN           NaN            NaN
# -mati-                            NaN           NaN            NaN
# -pavel-                           NaN           NaN            NaN
#
# opening_archetype    Anderssen Opening  Australian Defense  Barnes Defense  \
# player_id
# --jim--                            NaN                 NaN             NaN
# -0olo0-                            NaN                 NaN             NaN
# -l-_jedi_knight_-l-                NaN                 NaN             NaN
# -mati-                             NaN                 NaN             5.0
# -pavel-                            NaN                 NaN             NaN
#
# opening_archetype    Barnes Opening  Benko Gambit  Benko Gambit Accepted  \
# player_id
# --jim--                         NaN           NaN                    NaN
# -0olo0-                         NaN           NaN                    NaN
# -l-_jedi_knight_-l-             NaN           NaN                    NaN
# -mati-                          NaN           NaN                    NaN
# -pavel-                         NaN           NaN                    NaN
#
# opening_archetype    Benko Gambit Declined  ...  Trompowsky Attack  \
# player_id                                   ...
# --jim--                                NaN  ...                NaN
# -0olo0-                                NaN  ...                NaN
# -l-_jedi_knight_-l-                    NaN  ...                NaN
# -mati-                                 NaN  ...                NaN
# -pavel-                                NaN  ...                NaN
#
# opening_archetype    Valencia Opening  Van Geet Opening  Van't Kruijs Opening  \
# player_id
# --jim--                           NaN               NaN                   NaN
# -0olo0-                           NaN               NaN                   NaN
# -l-_jedi_knight_-l-               NaN               NaN                   NaN
# -mati-                            NaN               NaN                   NaN
# -pavel-                           NaN               NaN                   NaN
#
# opening_archetype    Vienna Game  Wade Defense  Ware Defense  Ware Opening  \
# player_id
# --jim--                      NaN           NaN           NaN           NaN
# -0olo0-                      NaN           NaN           NaN           NaN
# -l-_jedi_knight_-l-          NaN           NaN           NaN           NaN
# -mati-                       NaN           NaN           NaN           NaN
# -pavel-                      NaN           NaN           NaN           NaN
#
# opening_archetype    Yusupov-Rubinstein System  Zukertort Opening
# player_id
# --jim--                                    NaN                NaN
# -0olo0-                                    NaN                NaN
# -l-_jedi_knight_-l-                        NaN                NaN
# -mati-                                     NaN                NaN
# -pavel-                                    NaN                NaN
#
# [5 rows x 143 columns]

# %%
pd.Series(recommendations.values.flatten()).value_counts().sort_index().plot.bar()

# %%
from sklearn.metrics.pairwise import pairwise_distances
# user_similarity = pairwise_distances(train.fillna(0), metric='cosine')
item_similarity = pairwise_distances(recommendations.T.fillna(0), metric='cosine')

# %%
item_similarity.shape
# Out:
# (143, 143)

# %%
correction = np.array([np.abs(item_similarity).sum(axis=1)])
item_predictions = recommendations.fillna(0).dot(item_similarity).apply(
    lambda srs: srs / np.array([item_similarity.sum(axis=1)]).flatten(), axis='columns')

# %%
item_predictions.head()
# Out:
#                           0         1         2         3         4    \
# player_id
# --jim--              0.034214  0.035298  0.034367  0.035092  0.035176
# -0olo0-              0.034111  0.035145  0.034739  0.035220  0.035228
# -l-_jedi_knight_-l-  0.160214  0.162370  0.159469  0.161316  0.161615
# -mati-               0.035660  0.035462  0.035368  0.035475  0.034205
# -pavel-              0.034214  0.035298  0.034367  0.035092  0.035176
#
#                           5         6         7         8         9    ...  \
# player_id                                                              ...
# --jim--              0.035199  0.034965  0.035221  0.035357  0.035315  ...
# -0olo0-              0.035018  0.035152  0.034636  0.035042  0.035240  ...
# -l-_jedi_knight_-l-  0.161384  0.161451  0.162302  0.161885  0.162258  ...
# -mati-               0.000000  0.035295  0.035344  0.035357  0.035315  ...
# -pavel-              0.035199  0.034965  0.035221  0.035357  0.035315  ...
#
#                           133       134       135       136       137  \
# player_id
# --jim--              0.034979  0.035052  0.034727  0.034081  0.033884
# -0olo0-              0.034861  0.034196  0.034326  0.032170  0.034502
# -l-_jedi_knight_-l-  0.161831  0.161429  0.161212  0.158373  0.159964
# -mati-               0.035256  0.035238  0.035173  0.034849  0.035723
# -pavel-              0.034979  0.035052  0.034727  0.034081  0.033884
#
#                           138       139       140       141       142
# player_id
# --jim--              0.035128  0.035023  0.034451  0.035011  0.033724
# -0olo0-              0.034975  0.035269  0.034994  0.035148  0.034251
# -l-_jedi_knight_-l-  0.161762  0.161252  0.161136  0.161900  0.158805
# -mati-               0.035260  0.035139  0.035552  0.035399  0.034542
# -pavel-              0.035128  0.035023  0.034451  0.035011  0.033724
#
# [5 rows x 143 columns]

# %%
recommended_opening_numbers = item_predictions.apply(
    lambda srs: np.argmax(srs.values), axis='columns'
)
recommended_opening_numbers.head()
# Out:
# player_id
# --jim--                 25
# -0olo0-                129
# -l-_jedi_knight_-l-     56
# -mati-                 124
# -pavel-                 25
# dtype: int64

# %%
opening_names = pd.Series(recommendations.columns)
recommended_openings = recommended_opening_numbers.map(opening_names)

# %%
recommended_openings.head()
# Out:
# player_id
# --jim--                Center Game Accepted
# -0olo0-                              System
# -l-_jedi_knight_-l-    Hippopotamus Defense
# -mati-                     Sicilian Defense
# -pavel-                Center Game Accepted
# dtype: object

# %%
recommended_openings.value_counts().head(20).iloc[1:].plot.bar(figsize=(24, 10), fontsize=22)
