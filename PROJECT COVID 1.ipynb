# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("covid19_italy_region.csv")
data
# Out:
#        SNo                 Date Country  RegionCode             RegionName  \
# 0        0  2020-02-24T18:00:00     ITA          13                Abruzzo
# 1        1  2020-02-24T18:00:00     ITA          17             Basilicata
# 2        2  2020-02-24T18:00:00     ITA          18               Calabria
# 3        3  2020-02-24T18:00:00     ITA          15               Campania
# 4        4  2020-02-24T18:00:00     ITA           8         Emilia-Romagna
# 5        5  2020-02-24T18:00:00     ITA           6  Friuli Venezia Giulia
# 6        6  2020-02-24T18:00:00     ITA          12                  Lazio
# 7        7  2020-02-24T18:00:00     ITA           7                Liguria
# 8        8  2020-02-24T18:00:00     ITA           3              Lombardia
# 9        9  2020-02-24T18:00:00     ITA          11                 Marche
# 10      10  2020-02-24T18:00:00     ITA          14                 Molise
# ...

# %%
data.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'Latitude',
#        'Longitude', 'HospitalizedPatients', 'IntensiveCarePatients',
#        'TotalHospitalizedPatients', 'HomeConfinement', 'CurrentPositiveCases',
#        'NewPositiveCases', 'Recovered', 'Deaths', 'TotalPositiveCases',
#        'TestsPerformed'],
#       dtype='object')

# %%
data.tail()
# Out:
#        SNo                 Date Country  RegionCode     RegionName   Latitude  \
# 6022  6022  2020-12-06T17:00:00     ITA          19        Sicilia  38.115697
# 6023  6023  2020-12-06T17:00:00     ITA           9        Toscana  43.769231
# 6024  6024  2020-12-06T17:00:00     ITA          10         Umbria  43.106758
# 6025  6025  2020-12-06T17:00:00     ITA           2  Valle d'Aosta  45.737503
# 6026  6026  2020-12-06T17:00:00     ITA           5         Veneto  45.434905
#
#       Longitude  HospitalizedPatients  IntensiveCarePatients  \
# 6022  13.362357                  1367                    213
# 6023  11.255889                  1360                    252
# 6024  12.388247                   332                     60
# 6025   7.320149                   102                      8
# 6026  12.338452                  2508                    308
#
#       TotalHospitalizedPatients  HomeConfinement  CurrentPositiveCases  \
# ...

# %%
data.describe()
# Out:
#                SNo   RegionCode     Latitude    Longitude  \
# count  6027.000000  6027.000000  6027.000000  6027.000000
# mean   3013.000000    11.857143    43.046293    12.225955
# std    1739.989368     6.274319     2.488987     2.659168
# min       0.000000     1.000000    38.115697     7.320149
# 25%    1506.500000     7.000000    41.125596    11.121231
# 50%    3013.000000    12.000000    43.616760    12.388247
# 75%    4519.500000    17.000000    45.434905    13.768136
# max    6026.000000    22.000000    46.499335    16.867367
#
#        HospitalizedPatients  IntensiveCarePatients  TotalHospitalizedPatients  \
# count           6027.000000            6027.000000                6027.000000
# mean             509.093579              55.892318                 564.985897
# std             1272.731157             134.957979                1403.362341
# min                0.000000               0.000000                   0.000000
# ...

# %%
data.isnull().sum()
# Out:
# SNo                             0
# Date                            0
# Country                         0
# RegionCode                      0
# RegionName                      0
# Latitude                        0
# Longitude                       0
# HospitalizedPatients            0
# IntensiveCarePatients           0
# TotalHospitalizedPatients       0
# HomeConfinement                 0
# CurrentPositiveCases            0
# NewPositiveCases                0
# Recovered                       0
# Deaths                          0
# TotalPositiveCases              0
# TestsPerformed               1155
# dtype: int64

# %%
data.count()
# Out:
# SNo                          6027
# Date                         6027
# Country                      6027
# RegionCode                   6027
# RegionName                   6027
# Latitude                     6027
# Longitude                    6027
# HospitalizedPatients         6027
# IntensiveCarePatients        6027
# TotalHospitalizedPatients    6027
# HomeConfinement              6027
# CurrentPositiveCases         6027
# NewPositiveCases             6027
# Recovered                    6027
# Deaths                       6027
# TotalPositiveCases           6027
# TestsPerformed               4872
# dtype: int64

# %%
sns.relplot(x="TotalHospitalizedPatients",y="Recovered",data=data)

# %%
sns.relplot(x="TotalHospitalizedPatients",y="Deaths",data=data)

# %%
sns.relplot(x="TotalHospitalizedPatients",y="Deaths",hue="Recovered",data=data)

# %%
sns.pairplot(data)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
sns.relplot(x='HomeConfinement',y='TotalPositiveCases',kind='line',hue='Recovered',data=data)

# %%
# finding sum over index axis
# By default the axis is set to 0
data.sum(axis = 0, skipna = False)
# Out:
# SNo                                                                   18159351
# Date                         2020-02-24T18:00:002020-02-24T18:00:002020-02-...
# Country                      ITAITAITAITAITAITAITAITAITAITAITAITAITAITAITAI...
# RegionCode                                                               71463
# RegionName                   AbruzzoBasilicataCalabriaCampaniaEmilia-Romagn...
# Latitude                                                                259440
# Longitude                                                              73685.8
# HospitalizedPatients                                                   3068307
# IntensiveCarePatients                                                   336863
# TotalHospitalizedPatients                                              3405170
# HomeConfinement                                                       34491987
# CurrentPositiveCases                                                  37897157
# ...

# %%
sns.relplot(x='HomeConfinement',y='TotalPositiveCases',kind='line',hue='Recovered',data=data)

# %%
sns.catplot(x='Recovered',y='TotalPositiveCases',data=data)
