# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('Weather Data.csv')
data.head(10)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
# 5  1/1/2012 5:00    -1.4              -3.3         87                9
# 6  1/1/2012 6:00    -1.5              -3.1         89                7
# 7  1/1/2012 7:00    -1.4              -3.6         85                7
# 8  1/1/2012 8:00    -1.4              -3.6         85                9
# 9  1/1/2012 9:00    -1.3              -3.1         88               15
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# ...

# %%
data.size
# Out:
# 70272

# %%
data.shape
# Out:
# (8784, 8)

# %%
data.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
data.tail(10)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8774  12/31/2012 14:00    -3.4              -5.7         84                6
# 8775  12/31/2012 15:00    -2.3              -4.6         84                9
# 8776  12/31/2012 16:00    -1.4              -4.0         82               13
# 8777  12/31/2012 17:00    -1.1              -3.3         85               19
# 8778  12/31/2012 18:00    -1.3              -3.1         88               17
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa Weather
# 8774           11.3     100.57    Snow
# 8775            9.7     100.47    Snow
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
data.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
data['Temp_C'].unique()
# Out:
# array([ -1.8,  -1.5,  -1.4,  -1.3,  -1. ,  -0.5,  -0.2,   0.2,   0.8,
#          1.8,   2.6,   3. ,   3.8,   3.1,   3.2,   4. ,   4.4,   5.3,
#          5.2,   4.6,   3.9,   3.7,   2.9,   2.3,   2. ,   1.9,   1.5,
#          2.2,   1.7,   1.1,   0. ,  -0.7,  -2.1,  -4.1,  -4.8,  -5.6,
#         -5.8,  -7. ,  -7.4,  -9. ,  -9.7, -10.5, -11.3, -12.6, -12.9,
#        -13.3, -14. , -14.8, -15. , -15.3, -14.9, -15.1, -15.8, -16.3,
#        -16.9, -17.3, -17. , -17.1, -17.5, -17.9, -18.1, -18.5, -18.6,
#        -18.2, -17.8, -16.8, -15.2, -14.2, -13.7, -12.4, -10.2,  -9.4,
#         -8.9,  -8.4,  -7.8,  -7.6,  -9.5,  -9.6,  -8.8,  -7.5,  -5.4,
#         -5. ,  -8.2,  -7.1,  -6.1,  -6.6,  -6. ,  -4.7,  -4.4,  -5.1,
#         -4.3,  -6.7,  -9.2,  -9.8,  -9.9, -10. , -10.6, -11.8, -12. ,
#        -14.4, -12.3, -12.5, -11.7, -11.9, -11.2, -11.5, -11.6,  -9.3,
#         -8.7,  -8.5,  -8.1,  -6.9,  -6.4,  -5.7,  -5.5,  -3.7,  -3.6,
# ...

# %%
data['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
data.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
data.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
data.isnull
# Out:
# <bound method DataFrame.isnull of              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# 5        1/1/2012 5:00    -1.4              -3.3         87                9
# 6        1/1/2012 6:00    -1.5              -3.1         89                7
# 7        1/1/2012 7:00    -1.4              -3.6         85                7
# 8        1/1/2012 8:00    -1.4              -3.6         85                9
# 9        1/1/2012 9:00    -1.3              -3.1         88               15
# 10      1/1/2012 10:00    -1.0              -2.3         91                9
# ...

# %%
data['Weather'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Haze                                         16
# Thunderstorms,Rain Showers                   16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
# Date/Time           8784 non-null object
# Temp_C              8784 non-null float64
# Dew Point Temp_C    8784 non-null float64
# Rel Hum_%           8784 non-null int64
# Wind Speed_km/h     8784 non-null int64
# Visibility_km       8784 non-null float64
# Press_kPa           8784 non-null float64
# Weather             8784 non-null object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %% [markdown]
# # Unique Wind Speed

# %%
data['Wind Speed_km/h'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %%
data['Wind Speed_km/h'].nunique()
# Out:
# 34

# %% [markdown]
# # When Weather is Clear

# %%
data.head(10)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
# 5  1/1/2012 5:00    -1.4              -3.3         87                9
# 6  1/1/2012 6:00    -1.5              -3.1         89                7
# 7  1/1/2012 7:00    -1.4              -3.6         85                7
# 8  1/1/2012 8:00    -1.4              -3.6         85                9
# 9  1/1/2012 9:00    -1.3              -3.1         88               15
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# ...

# %%
data['Weather'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Haze                                         16
# Thunderstorms,Rain Showers                   16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
data[data.Weather == 'Clear']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# 241     1/11/2012 1:00   -10.7             -17.8         56               17
# 242     1/11/2012 2:00   -12.0             -18.9         56               19
# 243     1/11/2012 3:00   -12.7             -19.4         57               19
# 244     1/11/2012 4:00   -13.4             -20.1         57               17
# 344     1/15/2012 8:00   -23.3             -28.5         62                7
# 351    1/15/2012 15:00   -15.4             -22.8         53               24
# ...

# %%
data.groupby('Weather').get_group('Clear')
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# 241     1/11/2012 1:00   -10.7             -17.8         56               17
# 242     1/11/2012 2:00   -12.0             -18.9         56               19
# 243     1/11/2012 3:00   -12.7             -19.4         57               19
# 244     1/11/2012 4:00   -13.4             -20.1         57               17
# 344     1/15/2012 8:00   -23.3             -28.5         62                7
# 351    1/15/2012 15:00   -15.4             -22.8         53               24
# ...

# %% [markdown]
# # Wind Speed 4Km/Hr

# %%
data[data['Wind Speed_km/h'] == 4]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 96       1/5/2012 0:00    -8.8             -11.7         79                4
# 101      1/5/2012 5:00    -7.0              -9.5         82                4
# 146      1/7/2012 2:00    -8.1             -11.1         79                4
# 147      1/7/2012 3:00    -7.8             -10.8         79                4
# 149      1/7/2012 5:00    -6.9              -9.7         80                4
# 164     1/7/2012 20:00    -1.8              -3.7         87                4
# 166     1/7/2012 22:00    -1.5              -3.0         89                4
# 194      1/9/2012 2:00    -9.0             -14.1         66                4
# 339     1/15/2012 3:00   -20.7             -26.1         62                4
# ...

# %%
data[data['Wind Speed_km/h'] == 4].count()
# Out:
# Date/Time           474
# Temp_C              474
# Dew Point Temp_C    474
# Rel Hum_%           474
# Wind Speed_km/h     474
# Visibility_km       474
# Press_kPa           474
# Weather             474
# dtype: int64

# %%
data.isnull()
# Out:
#       Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0         False   False             False      False            False
# 1         False   False             False      False            False
# 2         False   False             False      False            False
# 3         False   False             False      False            False
# 4         False   False             False      False            False
# 5         False   False             False      False            False
# 6         False   False             False      False            False
# 7         False   False             False      False            False
# 8         False   False             False      False            False
# 9         False   False             False      False            False
# 10        False   False             False      False            False
# 11        False   False             False      False            False
# ...

# %%
data.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
data.notnull().sum()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %% [markdown]
# # Renaming Weather to Weather Conditions

# %%
data.head(3)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
#
#    Visibility_km  Press_kPa    Weather Conditions
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog

# %%
data=data.rename(columns = {'Weather' : 'Weather Conditions'})
data.head(2)
# OR 
# data.rename(columns = {'Weather' : 'Weather Conditions'}, inplace=True)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Conditions
# 0            8.0     101.24                Fog
# 1            8.0     101.24                Fog

# %% [markdown]
# # #Visibility

# %%
data.head(3)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
#
#    Visibility_km  Press_kPa    Weather Conditions
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog

# %%
data.Visibility_km.mean()
# Out:
# 27.66444672131151

# %% [markdown]
# # Standard Deviation of Pressure

# %%
data.Press_kPa.std()
# Out:
# 0.8440047459486474

# %% [markdown]
# # Variance

# %%
data['Rel Hum_%'].var()
# Out:
# 286.2485501984998

# %%
data.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %% [markdown]
# # Snow was Recorded

# %%
data['Weather Conditions'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Haze                                         16
# Thunderstorms,Rain Showers                   16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
data[data['Weather Conditions'] == 'Snow']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 55       1/3/2012 7:00   -14.0             -19.5         63               19
# 84      1/4/2012 12:00   -13.7             -21.7         51               11
# 86      1/4/2012 14:00   -11.3             -19.0         53                7
# 87      1/4/2012 15:00   -10.2             -16.3         61               11
# 88      1/4/2012 16:00    -9.4             -15.5         61               13
# 89      1/4/2012 17:00    -8.9             -13.2         71                9
# 90      1/4/2012 18:00    -8.9             -12.6         75               11
# 91      1/4/2012 19:00    -8.4             -12.7         71                9
# 92      1/4/2012 20:00    -7.8             -12.1         71                9
# 93      1/4/2012 21:00    -7.6             -11.6         73                7
# 94      1/4/2012 22:00    -9.5             -12.7         77                6
# ...

# %%
data[data['Weather Conditions'].str.contains('Snow')]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 41      1/2/2012 17:00    -2.1              -9.5         57               22
# 44      1/2/2012 20:00    -5.6             -13.4         54               24
# 45      1/2/2012 21:00    -5.8             -12.8         58               26
# 47      1/2/2012 23:00    -7.4             -14.1         59               17
# 48       1/3/2012 0:00    -9.0             -16.0         57               28
# 50       1/3/2012 2:00   -10.5             -15.8         65               22
# 51       1/3/2012 3:00   -11.3             -18.7         54               33
# 53       1/3/2012 5:00   -12.9             -19.1         60               22
# 54       1/3/2012 6:00   -13.3             -19.3         61               19
# 55       1/3/2012 7:00   -14.0             -19.5         63               19
# 84      1/4/2012 12:00   -13.7             -21.7         51               11
# ...

# %%
data['Weather Conditions'].str.contains('Snow').value_counts()
# Out:
# False    8201
# True      583
# Name: Weather Conditions, dtype: int64

# %%
data['Weather Conditions'].str.contains('Snow').unique()
# Out:
# array([False,  True])

# %%
data['Weather Conditions'].str.contains('Snow').sum()
# Out:
# 583

# %% [markdown]
# # WindSpeed is above 25 and Visibility is 25

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Conditions
# 0            8.0     101.24                Fog
# 1            8.0     101.24                Fog

# %%
data[(data['Wind Speed_km/h']>24) & (data['Visibility_km']==25)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 23      1/1/2012 23:00     5.3               2.0         79               30
# 24       1/2/2012 0:00     5.2               1.5         77               35
# 25       1/2/2012 1:00     4.6               0.0         72               39
# 26       1/2/2012 2:00     3.9              -0.9         71               32
# 27       1/2/2012 3:00     3.7              -1.5         69               33
# 28       1/2/2012 4:00     2.9              -2.3         69               32
# 29       1/2/2012 5:00     2.6              -2.3         70               32
# 30       1/2/2012 6:00     2.3              -2.6         70               26
# 31       1/2/2012 7:00     2.0              -2.9         70               33
# 42      1/2/2012 18:00    -4.1             -11.4         57               28
# 45      1/2/2012 21:00    -5.8             -12.8         58               26
# ...

# %% [markdown]
# # Mean value of each Wether condition column

# %%
data.groupby('Weather Conditions').mean()
# Out:
#                                             Temp_C  Dew Point Temp_C  \
# Weather Conditions
# Clear                                     6.825716          0.089367
# Cloudy                                    7.970544          2.375810
# Drizzle                                   7.353659          5.504878
# Drizzle,Fog                               8.067500          7.033750
# Drizzle,Ice Pellets,Fog                   0.400000         -0.700000
# Drizzle,Snow                              1.050000          0.150000
# Drizzle,Snow,Fog                          0.693333          0.120000
# Fog                                       4.303333          3.159333
# Freezing Drizzle                         -5.657143         -8.000000
# Freezing Drizzle,Fog                     -2.533333         -4.183333
# Freezing Drizzle,Haze                    -5.433333         -8.000000
# Freezing Drizzle,Snow                    -5.109091         -7.072727
# ...

# %%
data['Weather Conditions'].describe()
# Out:
# count             8784
# unique              50
# top       Mainly Clear
# freq              2106
# Name: Weather Conditions, dtype: object

# %%
data['Weather Conditions'].max()
# Out:
# 'Thunderstorms,Rain,Fog'

# %% [markdown]
# # MAx anf Min Value of Weather condition

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Conditions
# 0            8.0     101.24                Fog
# 1            8.0     101.24                Fog

# %%
data.groupby('Weather Conditions').describe()
# Out:
#                                          Temp_C                              \
#                                           count       mean        std   min
# Weather Conditions
# Clear                                    1326.0   6.825716  12.132015 -23.3
# Cloudy                                   1728.0   7.970544  11.000283 -21.4
# Drizzle                                    41.0   7.353659   5.297126   1.1
# Drizzle,Fog                                80.0   8.067500   4.970286   0.0
# Drizzle,Ice Pellets,Fog                     1.0   0.400000        NaN   0.4
# Drizzle,Snow                                2.0   1.050000   0.212132   0.9
# Drizzle,Snow,Fog                           15.0   0.693333   0.317280   0.3
# Fog                                       150.0   4.303333   8.038802 -16.0
# Freezing Drizzle                            7.0  -5.657143   2.024728  -9.0
# Freezing Drizzle,Fog                        6.0  -2.533333   2.122891  -6.4
# ...

# %%
data[data['Weather Conditions'] =='Fog']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# 5        1/1/2012 5:00    -1.4              -3.3         87                9
# 6        1/1/2012 6:00    -1.5              -3.1         89                7
# 7        1/1/2012 7:00    -1.4              -3.6         85                7
# 8        1/1/2012 8:00    -1.4              -3.6         85                9
# 9        1/1/2012 9:00    -1.3              -3.1         88               15
# 10      1/1/2012 10:00    -1.0              -2.3         91                9
# 11      1/1/2012 11:00    -0.5              -2.1         89                7
# 12      1/1/2012 12:00    -0.2              -2.0         88                9
# ...

# %% [markdown]
# # Weather clear and Visibility abbove 40km

# %%
data[(data['Weather Conditions'] == 'Clear') & (data['Visibility_km']>=40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 351    1/15/2012 15:00   -15.4             -22.8         53               24
# 352    1/15/2012 16:00   -15.1             -22.8         52               24
# 425    1/18/2012 17:00   -11.3             -18.8         54               26
# 440     1/19/2012 8:00   -13.7             -18.4         68               19
# 441     1/19/2012 9:00   -12.7             -17.2         69               17
# 496    1/21/2012 16:00   -11.6             -18.8         55                7
# 497    1/21/2012 17:00   -12.1             -19.8         53               11
# 704     1/30/2012 8:00   -10.5             -17.0         59                9
# 710    1/30/2012 14:00    -6.7             -15.0         52               22
# 823      2/4/2012 7:00   -11.0             -14.7         74                7
# 824      2/4/2012 8:00   -11.6             -15.6         72                9
# ...
